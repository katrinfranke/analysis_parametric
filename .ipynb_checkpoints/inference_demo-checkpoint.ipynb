# %%
import os
# make sure that either you have the .env set up, or uncomment that code block and fill in the keys
os.environ["CUDA_VISIBLE_DEVICES"] = "9"
os.environ["MLFLOW_TRACKING_URI"] = "https://mlflow.enigmatic.stanford.edu/"
os.environ["MLFLOW_TRACKING_USERNAME"] = "mlflow-runner"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "x3i#U9*73N75"

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

import torch
from torch import autocast
from mlflow.artifacts import download_artifacts
from hydra.utils import instantiate

from experanto.dataloaders import get_multisession_concat_dataloader
from monkey_baselines.model_factory import load_model
from monkey_baselines.utils.evals import get_correlation_gaze

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %load_ext dotenv
# %dotenv
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.7.0a0+7c8ec84dab.nv25.03 for torchao version 0.16.0             Please see https://github.com/pytorch/ao/issues/2919 for more info
# cannot find .env file

# %%
## MLflow run IDs for the two models used in this demo:
# V3/V4 model: https://mlflow.atlab.stanford.edu/#/experiments/609269488671045964/runs/eb4b088144dd407ebeb9f4a3c70f9cad
# V1/V2/V3 model: https://mlflow.atlab.stanford.edu/#/experiments/609269488671045964/runs/fe071b4bb2b244068889f4a2cc327d69

# %%
model_checkpoint_path = download_artifacts(
    "mlflow-artifacts:/621818231566971674/2f85fd6f5dda46e280456d3186618e1c/artifacts/6806be20120f307fa684cd4c637ad949_final.pth.tar"
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
config_path = download_artifacts(
    "mlflow-artifacts:/621818231566971674/2f85fd6f5dda46e280456d3186618e1c/artifacts/6806be20120f307fa684cd4c637ad949_final_cfg.pth.tar"
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
cfg = torch.load(config_path, weights_only=False)
cfg = instantiate(cfg)

# %% [markdown]
# # Get dataloaders

# %%
paths = [
    "/mnt/data1/enigma/goliath_10_20_sandbox/37_3843837605846_0_V3A_V4/",
]
cfg.dataset.modality_config.screen.valid_condition = {"tier": "train"}
cfg.dataset.modality_config.screen.include_blanks = True
cfg.dataset.modality_config.screen.sample_stride = 1
train_dl = get_multisession_concat_dataloader(paths, cfg)
cfg.dataset.modality_config.screen.sample_stride = cfg.dataset.modality_config.screen.chunk_size
# override blanks for validation
cfg.dataset.modality_config.screen.include_blanks = False
cfg.dataset.modality_config.screen.valid_condition = {"tier": "validation"}
val_dl = get_multisession_concat_dataloader(paths, cfg)

cfg.dataset.modality_config.screen.include_blanks = False
cfg.dataset.modality_config.screen.valid_condition = {"tier": "test"}
test_dl = get_multisession_concat_dataloader(paths, cfg)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Dataset 0: 37_3843837605846_0_V3A_V4, length = 215312
# Sessions: ['37_3843837605846_0_V3A_V4']
# Batches per session: {'37_3843837605846_0_V3A_V4': 26914}
# Total batches: 26914
# Created FastSessionDataLoader with 1 sessions and 26914 total batches
# Dataset 0: 37_3843837605846_0_V3A_V4, length = 1915
# Sessions: ['37_3843837605846_0_V3A_V4']
# Batches per session: {'37_3843837605846_0_V3A_V4': 239}
# Total batches: 239
# Created FastSessionDataLoader with 1 sessions and 239 total batches
# Dataset 0: 37_3843837605846_0_V3A_V4, length = 249
# Sessions: ['37_3843837605846_0_V3A_V4']
# Batches per session: {'37_3843837605846_0_V3A_V4': 31}
# Total batches: 31
# Created FastSessionDataLoader with 1 sessions and 31 total batches

# %% [markdown]
# # Get model

# %%
dtype = getattr(torch, cfg.trainer.dtype)
skip_samples = cfg.trainer.skip_n_samples # <=== This is super important

print("model dtype: ", dtype)
model = load_model(config_path, model_checkpoint_path, train_dl, strict=True, model_type="free_viewing")
# Out:
# model dtype:  torch.float32

# %% [markdown]
# ## Run inference

# %%
key, batch = next(iter(train_dl))

# these 3 inputs are required for inference. More details are below.
videos = batch["screen"].to("cuda", dtype, non_blocking=True)
gaze = batch["eye_tracker"][..., :2].cuda().to("cuda", dtype, non_blocking=True)
gaze_timestamps = batch["timestamps"]["eye_tracker"].to("cuda", dtype, non_blocking=True)

# ground truth neuronal responses. not an input to the model.
responses = batch["responses"].to("cuda", dtype, non_blocking=True)

# run forward pass
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(videos, key, gaze=gaze, gaze_timestamps=gaze_timestamps,)

print("responses: ", responses.shape, " (batch size, timestamps, neurons, ),  model has a context of 12 samples: 12/30 = 400ms)")
print("model output shape: ", out.shape, " (batch size, neurons, timestamps),  model has a context of 12 samples: 12/30 = 400ms)")
# Out:
# responses:  torch.Size([8, 12, 653])  (batch size, timestamps, neurons, ),  model has a context of 12 samples: 12/30 = 400ms)
# model output shape:  torch.Size([8, 653, 12])  (batch size, neurons, timestamps),  model has a context of 12 samples: 12/30 = 400ms)

# %% [markdown]
# ## >>> Important for inference/MEIs <<<

# %%
print(f"IMPORTANT!! The model is trained to predict a subset of responses, and it ignores the first {skip_samples} responses")

ground_truth_responses = responses[:, skip_samples:, :].cpu().numpy() # (batch size, valid timestamps, neurons)
predictions = out[:, :, skip_samples:].cpu().numpy() # (batch_size, neurons, valid timestamps)

print("model valid output shape: ", predictions.shape, " (batch size, neurons, [timestamps - skipped samples]), model makes valid predictions for 9 samples: 9/30 = 300ms)")
# Out:
# IMPORTANT!! The model is trained to predict a subset of responses, and it ignores the first 3 responses
# model valid output shape:  (8, 653, 9)  (batch size, neurons, [timestamps - skipped samples]), model makes valid predictions for 9 samples: 9/30 = 300ms)

# %% [markdown]
# ## Get validation score

# %%
from monkey_baselines.utils.evals import get_correlation_gaze

validation_correlation = get_correlation_gaze(
    model=model,
    dataloader=val_dl,
    amp=cfg.trainer.amp,
    valid_samples=cfg.trainer.skip_n_samples,
    dtype=dtype,
    per_session=True,
    per_neuron=True,
)

# %%
plt.hist(validation_correlation[key])
plt.xlabel("correlation")
plt.ylabel("number of neurons")
plt.title("Validation performance on all Neurons")
# Out:
# Text(0.5, 1.0, 'Validation performance on all Neurons')

# %% [markdown]
# # get unit info

# %%
import pandas as pd

# %%
base_path = "/mnt/data1/enigma/goliath_10_20_sandbox/37_3843837605846_0_V3A_V4/responses_30Hz_permissive_stability_criteria/meta/"
df_anatomy = pd.read_csv(base_path + "anatomical_info.csv") # estimated brain area from all units (N=1040 originally recorded units)
df_unit_info= pd.read_csv(base_path + "unit_summary.csv") # spike sorting quality control, for actual units used in model (N=653 units)

# %%
plt.bar(*np.unique(df_anatomy["label_name"], return_counts=True))
# Out:
# <BarContainer object of 3 artists>

# %%
df_anatomy # All 1040 neurons
# Out:
#       Unnamed: 0  unit_id  unit_depth_um  matched_voxel_pos_um    delta_um  \
# 0              0        0    3763.324303                3840.0  -76.675697
# 1              1        1    2415.414371                2340.0   75.414371
# 2              2        2    3764.891670                3840.0  -75.108330
# 3              3        3    3749.779073                3840.0  -90.220927
# 4              4        4    3770.891838                3840.0  -69.108162
# ...          ...      ...            ...                   ...         ...
# 1035        1035     1035    2440.147705                2340.0  100.147705
# 1036        1036     1036    2442.865534                2340.0  102.865534
# 1037        1037     1037     106.525236                  90.0   16.525236
# 1038        1038     1038     140.524952                  90.0   50.524952
# 1039        1039     1039    2416.909912                2340.0   76.909912
#
#       label_id    label_name
# 0            0  White Matter
# 1          123           V3A
# 2            0  White Matter
# 3            0  White Matter
# 4            0  White Matter
# ...        ...           ...
# 1035       123           V3A
# 1036       123           V3A
# 1037        20            V4
# 1038        20            V4
# 1039       123           V3A
#
# [1040 rows x 7 columns]

# %%
df_unit_info # 653 neurons used in modeling
# Out:
#            cluster_id KSLabel     probe_id  original_unit_id  presence_ratio  \
# 0       probe_imec0_1     mua  probe_imec0                 1        1.000000
# 1       probe_imec0_2    good  probe_imec0                 2        1.000000
# 2       probe_imec0_3    good  probe_imec0                 3        0.944751
# 3       probe_imec0_4    good  probe_imec0                 4        1.000000
# 4       probe_imec0_5    good  probe_imec0                 5        0.988950
# ..                ...     ...          ...               ...             ...
# 648  probe_imec0_1030     mua  probe_imec0              1030        1.000000
# 649  probe_imec0_1033     mua  probe_imec0              1033        0.856354
# 650  probe_imec0_1036     mua  probe_imec0              1036        1.000000
# 651  probe_imec0_1037     mua  probe_imec0              1037        1.000000
# 652  probe_imec0_1039     mua  probe_imec0              1039        1.000000
#
#      good_spikes_fraction        mfr        mifr   med_isi  mode_isi  ...  \
# 0                0.693142   6.448777   79.837902  0.065900  0.001000  ...
# 1                0.948761  21.135292  111.663492  0.020000  0.001000  ...
# 2                0.829823   1.296760   40.831511  0.163867  0.001267  ...
# 3                0.958043  10.075046   75.448825  0.036500  0.001000  ...
# 4                0.520103   4.242870   32.443699  0.066367  0.016104  ...
# ..                    ...        ...         ...       ...       ...  ...
# 648              0.529599   1.055037   25.435641  0.415833  0.001000  ...
# 649              0.730218   0.702371   15.278071  0.316717  0.001133  ...
# 650              0.585318   0.931321   18.856705  0.473933  0.001000  ...
# 651              0.565822   2.464771   40.392525  0.141233  0.001000  ...
# 652              0.649982   1.479996   28.415056  0.306783  0.001000  ...
#
#            IR        Lv        LvR       LcV        SI       SKW   std_isi  \
# 0    1.671490  1.218014  49.704725 -0.586677  0.178159  1.956200  0.206413
# 1    1.322873  0.979164  76.033674 -0.345589  0.121006  2.791534  0.071419
# 2    1.680119  1.210683  23.725732 -1.031467  0.181314  4.156661  1.815359
# 3    1.441035  1.065283  51.392715 -0.457032  0.139311  2.774838  0.150049
# 4    1.172869  0.845752  21.018860 -0.584687  0.100393  3.286908  0.426497
# ..        ...       ...        ...       ...       ...       ...       ...
# 648  1.817475  1.281142  12.639628 -1.529881  0.205578  2.756312  1.390551
# 649  1.577238  1.146428   9.575059 -1.616044  0.162465  4.141456  3.204623
# 650  1.790189  1.266942  10.122621 -1.715714  0.200682  2.948316  1.593493
# 651  1.772670  1.274281  23.760194 -0.848070  0.195884  2.560983  0.625748
# 652  1.842589  1.298914  14.754220 -1.209372  0.209916  2.107208  0.904188
#
#      burst_idx  acg_burst_vs_mfr  acg_oscill_vs_mfr
# 0       500.00         13.047929           3.284478
# 1       461.54          4.394114           2.035322
# 2       256.41         19.918783          12.925695
# 3       379.75          5.558238           2.934147
# 4       123.46          1.657742           4.662138
# ..         ...               ...                ...
# 648     111.88         13.532880           9.889340
# 649      60.54          8.801600          12.322230
# 650      84.72          9.888430           9.182106
# 651     198.68          6.253824           5.600418
# 652     136.99          9.245851           7.542667
#
# [653 rows x 25 columns]

# %%
is_v4 = np.isin(df_unit_info["original_unit_id"], np.where(df_anatomy["label_name"]=="V4")[0])
is_v3a = np.isin(df_unit_info["original_unit_id"], np.where(df_anatomy["label_name"]=="V3A")[0])
is_white_matter = np.isin(df_unit_info["original_unit_id"], np.where(df_anatomy["label_name"]=="White Matter")[0])

is_sua = (df_unit_info['KSLabel']=="good")
is_mua = (df_unit_info['KSLabel']=="mua")

# %%
fig, axs = plt.subplots(2,3, figsize=(20,8))

for i, (area, label) in enumerate(zip([is_v3a, is_v4, is_white_matter], ["V3", "V4", "White matter"])):
    for j, unit_type in enumerate([is_sua, is_mua]):
        y = validation_correlation[key][area & unit_type]
        
        corr = np.round(np.nanmean(y), 3)
        hist_data = axs[j, i].hist(y, bins=np.linspace(0, .8, 16), color="gray",)
        ymax = hist_data[0].max()
        axs[j, i].vlines(corr, ymin=0, ymax=ymax, colors="m", label="avg correlation = " + str(corr))
        axs[j, i].legend()
        axs[j, i].set(
            title=label, 
            ylabel="Single Units" if j==0 else "Multi Units"
                     )

# %% [markdown]
# # Select units for MEIs

# %% [markdown]
# ### example

# %%
correlations = validation_correlation[key]
filter_corr_value = 0.4

good_v3_sua_indices = np.where((correlations > 0.4) & is_sua & is_v3a)[0] # those are the indeces of the model neurons that correspond to that filter
print(f"Indices in the model that correspond to single neurons in area V3a with a correlation > {filter_corr_value}: ")
print(good_v3_sua_indices)
# all filters:
# brain area: [is_v4, is_v3a, is_white_matter]
# units: [is_sua, is_mua]
# Out:
# Indices in the model that correspond to single neurons in area V3a with a correlation > 0.4:
# [ 25  26  30  32  33  37  38  41  44  46  48  50  52  53  54  57  60  61
#   62  83  84  86  87  88  89  93  94  95  99 101 102 103 104 105 106 107
#  108 109 110 111 112 115 116 118 121 123 127 137 144 145 166 189 228 230
#  236 242 327 333 339 340 345 354 371 377 379 384 387 392 398 422 423 424
#  425 429 430 441 443 447 454 458 459 468 478 488 496 521 525 532 533 535]

# %% [markdown]
# ### select a unit

# %%
example_unit_index = 25
example_unit_id = df_unit_info.iloc[example_unit_index]["original_unit_id"]
print(f"unit index {example_unit_index} has corresponds to {correlations[example_unit_index]}")
# Out:
# unit index 25 has corresponds to 0.5054219961166382

# %% [markdown]
# ## visualize responses and predictions

# %% [markdown]
# ##### Important - as mentioned above, the model is trained to ignore the first N samples

# %%
print(f"the model skips over the first {skip_samples} samples and only makes valid predictions for the last {12-skip_samples} samples" )
# Out:
# the model skips over the first 3 samples and only makes valid predictions for the last 9 samples

# %%
key, batch = next(iter(val_dl))
videos = batch["screen"].to("cuda", dtype, non_blocking=True)
responses = batch["responses"].to("cuda", dtype, non_blocking=True)
gaze = batch["eye_tracker"][..., :2].cuda().to("cuda", dtype, non_blocking=True)
gaze_timestamps = batch["timestamps"]["eye_tracker"].to("cuda", dtype, non_blocking=True)

with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(videos, key, gaze=gaze, gaze_timestamps=gaze_timestamps,)


ground_truth_responses = responses[:, :, example_unit_index].cpu().numpy() # (batch size, timestamps, neurons)
predictions = out[:, example_unit_index, :].cpu().numpy() # (batch_size, neurons, timestamps)

# %% [markdown]
# ## show responses and predictions (to visualize more responses, run the cell above again to get a new batch+predictions)

# %%
fig, axs = plt.subplots(1, 8, figsize=(20,1))
for i, ax in enumerate(axs):
    # plot neuronal responses
    y = ground_truth_responses[i, skip_samples:]
    y_hat = predictions[i, skip_samples:]
    x = np.arange(len(y)) * (1000/30) # samples * sampling rate, converted to miliseconds
    
    ax.plot(x,y, color="gray", label="responses")
    ax.plot(x,y_hat, color="c", label="prediction")
    ax.set(title=f"neuron {example_unit_index}, trial {i}",
          xlabel="time in ms")
    #ax.axis("off")
    sns.despine()
    if i == 7:
        ax.legend(frameon=False, loc=(1.05, .5))
    if i == 0:
        ax.set(ylabel="firing rate (norm.)")

# %% [markdown]
# ## show corresponding eye movements

# %%
fig, axs = plt.subplots(1, 8, figsize=(20,2))
for i, ax in enumerate(axs):
    # plot eye gaze
    ax.plot(x, gaze[i, skip_samples:,0].cpu().numpy(), color="g", label="horizontal")
    ax.plot(x, gaze[i, skip_samples:,1].cpu().numpy(), color="b", label="vertical")
    ax.set(title=f"gaze, trial {i}", xlabel="time in ms")
    #ax.axis("off")
    sns.despine()
    if i == 7:
        ax.legend(frameon=False, loc=(1.05, .5))
    if i == 0:
        ax.set(ylabel="px offset from [0, 0]")

# %% [markdown]
# # Full MEI inference example

# %%
print(videos.shape)
print(gaze.shape)
print(gaze_timestamps.shape)
# Out:
# torch.Size([8, 3, 12, 236, 420])
# torch.Size([8, 12, 2])
# torch.Size([8, 12])

# %% [markdown]
# ### gaze set to zero => no eye movements

# %%
input_video = torch.randn(1,3,12,236, 420).cuda() # start with initial random noise video (batch, channels, t, h, w)
input_gaze = torch.zeros(1,12,2).cuda() # fix gaze to zeros => no eye movement 
input_gaze_timestamps = torch.ones(1,12).cuda() * 3600 # select a specific time in the experiment. No need to change it from this value.

# %%
# get predictions
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(input_video, key, gaze=input_gaze, gaze_timestamps=input_gaze_timestamps,)

# %%
print(f"predictions over time for the selected neuron: ")
print(out[0,example_unit_index, skip_samples:])
print(f"run gradient ascent on: {out[0, example_unit_index, skip_samples:].mean()}")
# Out:
# predictions over time for the selected neuron:
# tensor([0.6915, 0.6202, 0.6202, 0.6669, 0.6832, 0.6589, 0.6669, 0.6354, 0.5628],
#        device='cuda:0')
# run gradient ascent on: 0.6450929641723633

# %% [markdown]
# ### optimize MEI during an eye movement

# %%
## let's pick a trial from above where we have an eye movement in the beginning, and where we have a decent model prediction
# batch item 0 looks good

# %%
input_video = torch.randn(1,3,12,236, 420).cuda() # (batch, channels, t, h, w)
input_gaze = gaze[0, ...][None, ...] # select the gaze from the dataloader
input_gaze_timestamps = gaze_timestamps[0, ...][None, ...] # select the timestamp from the dataloader

# %%
# get predictions
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(input_video, key, gaze=input_gaze, gaze_timestamps=input_gaze_timestamps,)

# %%
print(f"predictions over time for the selected neuron: ")
print(out[0, example_unit_index, skip_samples:])
print(f"run gradient ascent on: {out[0, example_unit_index, skip_samples:].mean()}")
# Out:
# predictions over time for the selected neuron:
# tensor([0.8389, 0.7713, 0.7806, 0.7806, 0.7004, 1.0400, 1.9830, 1.8521, 1.6610],
#        device='cuda:0')
# run gradient ascent on: 1.1564459800720215

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Load model for V1/V2/V3

# %% [markdown]
# ### CHANGES COMPARED TO ABOVE MODEL
# - chunksize = 16 => the context is 530 ms, see the dataloader output shapes
# - there are 2 sessions in the dataloader/model
# - no anatomical information

# %%
model_checkpoint_path = download_artifacts(
    "mlflow-artifacts:/609269488671045964/fe071b4bb2b244068889f4a2cc327d69/artifacts/aaa4c076c986ff04910a4a6fc249c204_final.pth.tar"
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
config_path = download_artifacts(
    "mlflow-artifacts:/609269488671045964/fe071b4bb2b244068889f4a2cc327d69/artifacts/aaa4c076c986ff04910a4a6fc249c204_final_cfg.pth.tar"
)
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
cfg = torch.load(config_path, weights_only=False)
cfg = instantiate(cfg)

# %% [markdown]
# # Get dataloaders

# %%
paths = [
    "/mnt/data1/enigma/goliath_malachi_v0_3_0/35_3832523516180_1_V2_V3d/",
    "/mnt/data1/enigma/goliath_malachi_v0_3_0/35_3832433151864_1_V1/",
]
cfg.dataset.modality_config.screen.valid_condition = {"tier": "train"}
cfg.dataset.modality_config.screen.include_blanks = True
cfg.dataset.modality_config.screen.sample_stride = 1
train_dl = get_multisession_concat_dataloader(paths, cfg)
cfg.dataset.modality_config.screen.sample_stride = cfg.dataset.modality_config.screen.chunk_size
# override blanks for validation
cfg.dataset.modality_config.screen.include_blanks = False
cfg.dataset.modality_config.screen.valid_condition = {"tier": "validation"}
val_dl = get_multisession_concat_dataloader(paths, cfg)

cfg.dataset.modality_config.screen.include_blanks = False
cfg.dataset.modality_config.screen.valid_condition = {"tier": "test"}
test_dl = get_multisession_concat_dataloader(paths, cfg)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Dataset 0: 35_3832523516180_1_V2_V3d, length = 187002
# Dataset 1: 35_3832433151864_1_V1, length = 186399
# Sessions: ['35_3832523516180_1_V2_V3d', '35_3832433151864_1_V1']
# Batches per session: {'35_3832523516180_1_V2_V3d': 23375, '35_3832433151864_1_V1': 23299}
# Total batches: 46674
# Created FastSessionDataLoader with 2 sessions and 46674 total batches
# Dataset 0: 35_3832523516180_1_V2_V3d, length = 1321
# Dataset 1: 35_3832433151864_1_V1, length = 1348
# Sessions: ['35_3832523516180_1_V2_V3d', '35_3832433151864_1_V1']
# Batches per session: {'35_3832523516180_1_V2_V3d': 165, '35_3832433151864_1_V1': 168}
# Total batches: 333
# Created FastSessionDataLoader with 2 sessions and 333 total batches

# %% [markdown]
# # Get model

# %%
dtype = getattr(torch, cfg.trainer.dtype)
skip_samples = cfg.trainer.skip_n_samples # <=== This is super important

model = load_model(config_path, model_checkpoint_path, train_dl, strict=True, model_type="free_viewing")

# %% [markdown]
# ## Run inference

# %%
key, batch = next(iter(train_dl))

# these 3 inputs are required for inference. More details are below.
videos = batch["screen"].to("cuda", dtype, non_blocking=True)
gaze = batch["eye_tracker"][..., :2].cuda().to("cuda", dtype, non_blocking=True)
gaze_timestamps = batch["timestamps"]["eye_tracker"].to("cuda", dtype, non_blocking=True)

# ground truth neuronal responses. not an input to the model.
responses = batch["responses"].to("cuda", dtype, non_blocking=True)

# run forward pass
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(videos, key, gaze=gaze, gaze_timestamps=gaze_timestamps,)

print("responses: ", responses.shape, " (batch size, timestamps, neurons, ),  model has a context of 12 samples: 12/30 = 400ms)")
print("model output shape: ", out.shape, " (batch size, neurons, timestamps),  model has a context of 12 samples: 12/30 = 400ms)")
# Out:
# responses:  torch.Size([8, 16, 404])  (batch size, timestamps, neurons, ),  model has a context of 12 samples: 12/30 = 400ms)
# model output shape:  torch.Size([8, 404, 16])  (batch size, neurons, timestamps),  model has a context of 12 samples: 12/30 = 400ms)

# %%
print(videos.shape)
print(gaze.shape)
print(gaze_timestamps.shape)
# Out:
# torch.Size([8, 3, 16, 236, 420])
# torch.Size([8, 16, 2])
# torch.Size([8, 16])

# %% [markdown]
# ## Get validation score

# %%
from monkey_baselines.utils.evals import get_correlation_gaze

validation_correlation = get_correlation_gaze(
    model=model,
    dataloader=val_dl,
    amp=cfg.trainer.amp,
    valid_samples=cfg.trainer.skip_n_samples,
    dtype=dtype,
    per_session=True,
    per_neuron=True,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32). Setting the correlation coefficient to nan.
#   warnings.warn(*args, **kwargs)

# %%
## this dataloader and model has two sessions:
train_dl.dataset.session_names
# Out:
# ['35_3832523516180_1_V2_V3d', '35_3832433151864_1_V1']

# %%
data_key_v1 = "35_3832433151864_1_V1"
data_key_v2_3 = "35_3832523516180_1_V2_V3d"

# %%
np.nanmean(validation_correlation[data_key_v1])
# Out:
# 0.33385584

# %%
np.nanmean(validation_correlation[data_key_v2_3])
# Out:
# 0.26857373

# %% [markdown]
# ## V1

# %% [markdown]
# ### for these sessions, we don't have any anatomical data yet, just the unit info

# %%
base_path = "/mnt/data1/enigma/goliath_malachi_v0_3_0/35_3832433151864_1_V1/responses_30Hz_permissive_stability_criteria/meta/"
df_unit_info= pd.read_csv(base_path + "unit_summary.csv") # spike sorting quality control, for actual units used in model (N=653 units)

# %%
df_unit_info
# Out:
#         cluster_id KSLabel   probe_id  original_unit_id  presence_ratio  \
# 0      probe_2_1_0     mua  probe_2_1                 0        1.000000
# 1      probe_2_1_1     mua  probe_2_1                 1        0.989011
# 2      probe_2_1_2     mua  probe_2_1                 2        1.000000
# 3      probe_2_1_3     mua  probe_2_1                 3        1.000000
# 4      probe_2_1_4     mua  probe_2_1                 4        1.000000
# ..             ...     ...        ...               ...             ...
# 516  probe_2_1_709     mua  probe_2_1               709        1.000000
# 517  probe_2_1_710    good  probe_2_1               710        0.978022
# 518  probe_2_1_711    good  probe_2_1               711        1.000000
# 519  probe_2_1_713    good  probe_2_1               713        1.000000
# 520  probe_2_1_714    good  probe_2_1               714        1.000000
#
#      good_spikes_fraction        mfr       mifr   med_isi  mode_isi  ...  \
# 0                0.651132   9.220556  47.518159  0.069700  0.001000  ...
# 1                0.616092   0.762452  11.798212  0.802333  0.001033  ...
# 2                0.791307   4.082536  27.914477  0.158000  0.001000  ...
# 3                0.813270   1.722685  18.368299  0.346133  0.001000  ...
# 4                0.530389  11.733630  49.484092  0.057433  0.001000  ...
# ..                    ...        ...        ...       ...       ...  ...
# 516              0.507007   7.418099  81.606821  0.040633  0.001000  ...
# 517              0.693462   3.312158  31.358740  0.112767  0.001033  ...
# 518              0.497175  20.504408  70.538374  0.028000  0.004023  ...
# 519              0.763890   8.894497  45.183193  0.053000  0.001000  ...
# 520              0.817553  28.113027  89.397465  0.018500  0.003746  ...
#
#            IR        Lv        LvR       LcV        SI       SKW   std_isi  \
# 0    1.371572  1.008082  31.778525 -0.453037  0.128996  1.666877  0.112379
# 1    1.620385  1.146743   5.154593 -2.995280  0.172655  2.041392  1.508313
# 2    1.470612  1.071652  17.288232 -0.663849  0.146028  1.646821  0.256511
# 3    1.590937  1.141957   9.672942 -1.138892  0.166489  2.075776  0.672776
# 4    1.309914  0.964235  34.437071 -0.400561  0.119199  1.544724  0.083873
# ..        ...       ...        ...       ...       ...       ...       ...
# 516  1.613637  1.194031  57.482903 -0.529816  0.167137  2.270873  0.204443
# 517  1.443557  1.068325  19.834354 -0.711792  0.140299  2.614504  0.455295
# 518  1.196283  0.878870  48.140840 -0.318011  0.101306  1.948515  0.054251
# 519  1.163089  0.844764  31.888436 -0.438256  0.098064  3.181400  0.169715
# 520  1.127811  0.825144  57.307866 -0.282437  0.091538  2.429597  0.044217
#
#      burst_idx  acg_burst_vs_mfr  acg_oscill_vs_mfr
# 0       214.29          1.882604           1.346541
# 1        32.74          9.045229           8.040204
# 2       123.97          2.202004           2.202004
# 3        73.89          4.647793           4.041559
# 4       214.29          1.715875           1.301302
# ..         ...               ...                ...
# 516     483.87         10.479237           3.447185
# 517     137.61          2.485527           5.868941
# 518     254.24          1.249997           1.540933
# 519     204.08          3.456898           2.130926
# 520     280.37          1.806128           1.899528
#
# [521 rows x 25 columns]

# %% [markdown]
# ## example good v1 single neurons

# %%
np.where((df_unit_info["KSLabel"]=="good") & (validation_correlation[data_key_v1] > 0.6))
# Out:
# (array([  8,  66,  87, 103, 110, 139, 141, 154, 165, 175, 180, 181, 188,
#         192, 198, 244, 255, 270, 284, 296, 298, 321, 336, 359, 370, 405,
#         413, 448, 452, 454, 460, 512]),)

# %%
example_v1_unit = 8

# %%
# run forward pass
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(videos, key=data_key_v1, gaze=gaze, gaze_timestamps=gaze_timestamps,)

# %%
out.shape
# Out:
# torch.Size([8, 521, 16])

# %%
predictions = out[0, example_v1_unit, skip_samples:]

# %% [markdown]
# ## v2/v3

# %%
base_path = "/mnt/data1/enigma/goliath_malachi_v0_3_0/35_3832523516180_1_V2_V3d/responses_30Hz_permissive_stability_criteria/meta/"
df_unit_info= pd.read_csv(base_path + "unit_summary.csv") # spike sorting quality control, for actual units used in model (N=653 units)

# %%
df_unit_info
# Out:
#         cluster_id KSLabel   probe_id  original_unit_id  presence_ratio  \
# 0      probe_2_1_0     mua  probe_2_1                 0             1.0
# 1      probe_2_1_1     mua  probe_2_1                 1             1.0
# 2      probe_2_1_2    good  probe_2_1                 2             1.0
# 3      probe_2_1_3     mua  probe_2_1                 3             1.0
# 4      probe_2_1_4    good  probe_2_1                 4             1.0
# ..             ...     ...        ...               ...             ...
# 399  probe_2_1_519     mua  probe_2_1               519             1.0
# 400  probe_2_1_521    good  probe_2_1               521             1.0
# 401  probe_2_1_522     mua  probe_2_1               522             1.0
# 402  probe_2_1_524     mua  probe_2_1               524             1.0
# 403  probe_2_1_528     mua  probe_2_1               528             1.0
#
#      good_spikes_fraction        mfr       mifr   med_isi  mode_isi  ...  \
# 0                0.586563  13.799670  61.191152  0.043900  0.002988  ...
# 1                0.406064   0.626156   5.365325  0.954633  0.001367  ...
# 2                0.932397  19.458661  69.719915  0.030667  0.002431  ...
# 3                0.366098   6.201664  47.208185  0.090467  0.005758  ...
# 4                0.718655  20.738959  62.336879  0.032867  0.003521  ...
# ..                    ...        ...        ...       ...       ...  ...
# 399              0.544111   0.781868  12.102435  0.883100  0.001033  ...
# 400              0.845127   3.275590  79.613108  0.042633  0.001267  ...
# 401              0.650244   1.708997  52.966762  0.291733  0.001100  ...
# 402              0.490767   1.113329  16.017431  0.507900  0.001000  ...
# 403              0.627789   0.846680  19.328991  0.749067  0.001067  ...
#
#            IR        Lv        LvR       LcV        SI       SKW   std_isi  \
# 0    1.306943  0.965762  42.652986 -0.385325  0.118036  1.681786  0.077422
# 1    1.450940  1.051350   3.861633 -5.424004  0.143243  1.888212  1.802205
# 2    1.238535  0.917684  49.952442 -0.330004  0.107075  1.703117  0.054828
# 3    1.582228  1.169506  30.384676 -0.565938  0.162466  1.704567  0.188111
# 4    1.162608  0.852615  45.345460 -0.304371  0.096107  1.676070  0.046802
# ..        ...       ...        ...       ...       ...       ...       ...
# 399  1.576481  1.100778   4.817202 -3.390552  0.167615  1.328964  1.241582
# 400  2.007826  1.420197  50.771227 -0.712537  0.236486  2.332070  0.527344
# 401  2.015465  1.378251  21.410495 -1.171523  0.242136  1.741760  0.724639
# 402  1.637108  1.168070   8.278383 -1.669509  0.174969  1.707287  1.030467
# 403  1.725518  1.194517   6.802416 -2.542517  0.192418  1.430844  1.236415
#
#      burst_idx  acg_burst_vs_mfr  acg_oscill_vs_mfr
# 0       267.86          1.768341           1.531675
# 1        19.65          4.597137           6.129516
# 2       283.02          1.646336           1.404380
# 3       218.98          4.322298           3.244171
# 4       238.10          1.360362           1.193716
# ..         ...               ...                ...
# 399      32.24         13.098635           4.678084
# 400     410.96         18.568929           8.036445
# 401     434.78         36.667232           6.137458
# 402      64.20          6.231555           6.231555
# 403      59.90         22.634620           8.083679
#
# [404 rows x 25 columns]

# %% [markdown]
# ## example good v2/3 single neurons

# %%
np.where((df_unit_info["KSLabel"]=="good") & (validation_correlation[data_key_v2_3] > 0.5))
# unfortunately, at the moment there is no way to tell if a neuron is v2 or v3
# Out:
# (array([ 22,  52,  62,  63,  69,  70,  74,  84,  95, 105, 118, 121, 130,
#         133, 141, 227]),)

# %%
example_v2_3_unit = 22

# %%
# run forward pass
with torch.no_grad():
    with autocast(device_type="cuda", dtype=torch.bfloat16, enabled=cfg.trainer.amp):
        out = model(videos, key=data_key_v2_3, gaze=gaze, gaze_timestamps=gaze_timestamps,)

# %%
predictions = out[0, example_v2_3_unit, skip_samples:]

# %%
predictions
# Out:
# tensor([2.2668e-05, 2.2668e-05, 1.8559e-05, 1.8559e-05, 1.6793e-05, 1.5195e-05,
#         1.3749e-05, 1.5195e-05, 1.5195e-05, 1.5195e-05, 1.5195e-05, 1.5195e-05,
#         1.6793e-05], device='cuda:0')
